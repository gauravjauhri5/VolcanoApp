# %%
import streamlit as st # type: ignore
import pandas as pd
import json
import plotly.graph_objects as go
import plotly.express as px
import plotly.io as pio
from copy import deepcopy

@st.cache_data   
def load_data(path):
    df = pd.read_csv(path)
    return df

@st.cache_data   
def load_json(path):
    df = json.load(open(path))
    return df


vol_df = load_data('./volcano_ds_pop.csv')
vol_json = load_json('./countries.geojson')

print(vol_df.head())

# print(vol_json.head())


for i in vol_df["Country"].unique():
    print(i)
# Out:
# 2025-05-27 14:36:14.633 No runtime found, using MemoryCacheStorageManager
# 2025-05-27 14:36:14.635 No runtime found, using MemoryCacheStorageManager
#    Unnamed: 0    Number     Volcano Name        Country         Region  \
# 0           0  0803-001              Abu          Japan   Honshu-Japan
# 1           1  1505-096       Acamarachi          Chile        Chile-N
# 2           2  1402-08=       Acatenango      Guatemala      Guatemala
# 3           3  0103-004  Acigol-Nevsehir         Turkey         Turkey
# 4           4  1201-04-            Adams  United States  US-Washington
#
#    Latitude  Longitude    Elev            Type            Status Last Known  \
# 0    34.500    131.600   571.0  Shield volcano          Holocene    Unknown
# 1   -23.300    -67.620  6046.0   Stratovolcano          Holocene    Unknown
# 2    14.501    -90.876  3976.0   Stratovolcano        Historical         D1
# 3    38.570     34.520  1689.0            Maar          Holocene          U
# 4    46.206   -121.490  3742.0   Stratovolcano  Tephrochronology         D6
#
#    Population (2020)
# 0        126407422.0
# 1         19144605.0
# 2         17971382.0
# 3         84495243.0
# 4        331341050.0
# Japan
# Chile
# Guatemala
# Turkey
# United States
# Ethiopia
# Armenia
# Portugal
# Indonesia
# Russia
# Italy
# Ecuador
# Eritrea
# Canada
# Philippines
# Papua New Guinea
# Madagascar
# Vanuatu
# Peru
# Argentina
# El Salvador
# Nicaragua
# Djibouti
# Costa Rica
# Yemen
# Iceland
# Algeria
# Mexico
# New Zealand
# Colombia
# India
# Kenya
# Panama
# Vietnam
# Sudan
# Iran
# Saudi Arabia
# Nigeria
# Malaysia
# Uganda
# Mongolia
# Spain
# Cameroon
# North Korea
# France
# Bolivia
# Tonga
# Afghanistan
# Dominica
# Syria
# Comoros
# South Korea
# Libya
# China
# Tanzania
# Georgia
# Netherlands
# Fiji
# Chad
# Taiwan
# Sweden
# Myanmar
# South Africa
# Greece
# Australia
# United Kingdom
# Martinique
# Equatorial Guinea
# Sao Tome & Principe
# Samoa
# Guadeloupe
# Montserrat
# Grenada
# Honduras
# American Samoa
# Rwanda
# Wallis & Futuna
# Germany
